# %%
12+4-5
# Out:
# 11

# %%
2**10
# Out:
# 1024

# %%
a = var('a')
a^10
a
# Out:
# a

# %%
a = var('a')
a = a^10
a
# Out:
# a^10

# %%
sin(pi/2)
# Out:
# 1

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
14+2(5-3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e539137dd4db> in <module>()
# ----> 1 Integer(14)+Integer(2)(Integer(5)-Integer(3))
#
# TypeError: 'sage.rings.integer.Integer' object is not callable

# %%
14+2*(5-3)
# Out:
# 18

# %%
x = var('x')

# %%
eq1 = x^4-(3/2)*x^3-x+(3/2)==0

# %%
solve(eq1,x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
eq2 = sqrt(x**2+2*x) == 3

# %%
solve(eq2,x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d85c8e131ce1> in <module>()
# ----> 1 solve(eq2,x)
#
# NameError: name 'eq2' is not defined

# %%
solve(eq2,x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d85c8e131ce1> in <module>()
# ----> 1 solve(eq2,x)
#
# NameError: name 'eq2' is not defined

# %%
x = var('x')

# %%
eq2 = sqrt(x**2+2*x) == 3

# %%
solve(eq2,x)
# Out:
# [x == -sqrt(10) - 1, x == sqrt(10) - 1]

# %%
x,y = var('x,y')
syst = [2*x+y==0, x+3*y==-1]
solve(syst,x,y)
# Out:
# [[x == (1/5), y == (-2/5)]]

# %%
x,y = var('x,y')
syst = [2*x+x*y+2*y==59,3*x-2*x*y+3*y==-34]
solve(syst,x,y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
x = var('x')
limit((sin(x))/x,x=0)
# Out:
# 1

# %%
x = var('x')
limit((x^3+3x^2-5)/(2x^3-7*x),x=infinity)
# Out:
#   File "<ipython-input-21-d361777c416c>", line 2
#     limit((x**Integer(3)+3x**Integer(2)-Integer(5))/(2x**Integer(3)-Integer(7)*x),x=infinity)
#                           ^
# SyntaxError: invalid syntax

# %%
x = var('x')
limit((x^3+3*(x^2)-5)/(2*(x^3)-7*x),x=infinity)
# Out:
# 1/2

# %%
x = var('x')
limit((cos(x)+1)/(x-pi), x=pi)
# Out:
# 0

# %%
x = var('x')
y(x)=3*(x^3)+2*(x^2)-5
diff(y(x),1)
# Out:
# 9*x^2 + 4*x

# %%
x = var('x')
y(x)=sqrt(1+x^4)
diff(y(x),1)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %%
x = var('x')
y(x)=exp(x)*sin(x)*cos(x)
diff(y(x),1)
# Out:
# cos(x)^2*e^x + cos(x)*e^x*sin(x) - e^x*sin(x)^2

# %%
x = var('x')
f(x)= 3*(x^3)+2*(x^2)-5
integral_numerical(f(x),0,1)
# Out:
# (-3.5833333333333326, 3.978299171573477e-14)

# %%
x = var('x')
f(x)= 3*(x^3)+2*(x^2)-5
integrate(f(x),x,0,1)
# Out:
# -43/12

# %%
x = var('x')
f(x) = 1/(x^2)
integrate(f(x),x,1,infinity)
# Out:
# 1

# %%
x = var('x')
f(x) = exp(-(x^2))
integrate(f(x), x, -infinity, infinity)
# Out:
# sqrt(pi)

# %%
x = var('x')
f(x) = exp(-x)
plot(f(x),-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,r = var('x,r')
f(x,r)= ((200*exp(r*x))/(2*(exp(r*x)-1)+100))
listr = [-0.5,0.5]
f_list = [f(x,r) for r in listr]
plot(f_list,0,50)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
x = var('x')
f(x) = x * sin(1/x)
plot(f(x),-3,3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x(t) = (1-cos(t))*cos(t)
y(t) = (1-cos(t))*sin(t)
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x(t) = (sin(3*t))*cos(t)
y(t) = (sin(3*t))*sin(t)
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x(t) = (t-sin(t))
y(t) = (1-cos(t))
parametric_plot((x(t),y(t)),(t,0,6*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x(t) = cos(t) + (cos(7*t))/2 + (sin(17*t))/3
y(t) = sin(t) + (sin(7*t))/2 + (cos(17*t))/3
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t,s = var('t,s')
f(t,s) = 1 - ((s*cos(4*t)*cos(t))/sqrt(1-s^2*(cos(4*5))^2*(sin(t))^2)
x(t) = f(t-(pi/2),s)
y(t) = f(t,s)
# Out:
#   File "<ipython-input-41-c902fc5dec4c>", line 3
#     __tmp__=var("t"); x = symbolic_expression(f(t-(pi/Integer(2)),s)).function(t)
#           ^
# SyntaxError: invalid syntax

# %%
t,s= var('t,s')
f(t,s)= 1 - (((0.5)*cos(4*t)*cos(t))/sqrt(1-(0.5)^2*(cos(4*5))^2*(sin(t))^2)
x(t)= f(t-(pi/2),0.5)
y(t)= f(t,0.5)     
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
#   File "<ipython-input-42-5f809c29bb3e>", line 3
#     __tmp__=var("t"); x = symbolic_expression(f(t-(pi/Integer(2)),RealNumber('0.5'))).function(t)
#           ^
# SyntaxError: invalid syntax

# %%
t,s= var('t,s')
f(t,s)= 1 - ((s*cos(4*t)*cos(t))/sqrt(1-s^2*(cos(4*t))^2*(sin(t))^2))
x(t)= f(t-(pi/2),0.5)
y(t)= f(t,0.5)     
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t,s= var('t,s')
f(t,s)= 1 - ((s*cos(4*t)*cos(t))/sqrt(1-s^2*(cos(4*t))^2*(sin(t))^2))
g = parametric_plot((f(t-(pi/2),1/10),f(t,1/10)),(t,0,2*pi))
for k in [2..10]:
    g1 = parametric_plot((f(t-(pi/2),k/10),f(t,k/10)),(t,0,2*pi))
    g = g+g1
show(g)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
x,y = var('x,y')
f(x,y) = x^2 + y^2 - 2*x - 4*y
implicit_plot(f(x,y) == -4,(x,-4,4),(y,-4,4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x,y')
f(x,y) = x^2 - 2*x*y - y^2
implicit_plot(f(x,y) == 1,(x,-1,1),(y,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x,y')
f(x,y) = 6*(x^2) - 4*x*y + 9*(y^2) - 4*x - 32*y
implicit_plot(f(x,y) == 6,(x,-6,6),(y,-6,6))
# Out:
# Graphics object consisting of 1 graphics primitive
