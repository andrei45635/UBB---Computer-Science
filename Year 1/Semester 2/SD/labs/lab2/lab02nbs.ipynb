# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(2*x)*(1+y**2)
eqd

# %%
show(eqd)
# Out:
# y(x)/x + diff(y(x), x) == x^3

# %%
sol=desolve(eqd,y)
sol
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
show(sol)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
sol_l=solve(sol,y)
show(sol_l)
# Out:
# []

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(-2*x*(y**2))/((x**2)-1)
sol=desolve(eqd,y,show_method=True)
show(sol)
# Out:
# [1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1), 'separable']

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==((x^2)+(y^2))/(2*(x^2))
sol=desolve(eqd,y)
_C=var('_C')
show(sol.substitute(_C==1))
sol1=sol.substitute(_C==1)
# Out:
# x == e^(2*x/(x - y(x)))

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==-(x+y)/y
sol=desolve(eqd,y)
_C=var('_C')
#show(sol.substitute(_C==1))
sol1=sol.substitute(_C==1)
yy=var('yy')
sol1_g=sol1.substitute(y(x)==yy)
show(sol1_g)
implicit_plot(sol1_g,(x,-5,5),(yy,-5,5))
# Out:
# x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*yy + yy^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*yy)/x)))
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+diff(y,x)==sin(x)+cos(x)
sol=desolve(eqd,y)
show(sol)
# Out:
# _K2*e^(-x) + _K1 - cos(x)

# %%
_K2,_K1=var('_K2,_K1')
sol_g=sol.substitute(_K1==1,_K2==1)
show(sol_g)
# Out:
# -cos(x) + e^(-x) + 1

# %%
plot(sol_g,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)==exp(2*x)
sol=desolve(eqd,y)
show(sol)
# Out:
# _K1*e^x + _K2 + 1/2*e^(2*x)

# %%
f(x,_K1,_K2)=sol
show(f(x,_K1,_K2))
# Out:
# _K1*e^x + _K2 + 1/2*e^(2*x)

# %%
plot(f(x,-1,-1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)==1/(1+exp(x))
sol=desolve(eqd,y)
show(sol)
# Out:
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)

# %%
f(x,_K1,_K2)=sol
f_list=[f(x,_K1/10,1) for _K1 in [11..20]]
plot(f_list,-1,1)
# Out:
# Graphics object consisting of 10 graphics primitives

# %% [markdown]
# # Ex 2

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
sol=desolve(eqd,y,ics=[0,1])
show(sol)
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
sol_g=solve(sol,y)
show(sol_g)
# Out:
# [y(x) == tan(1/4*pi + x)]

# %%
sol_g
# Out:
# [y(x) == tan(1/4*pi + x)]

# %%
show(sol_g)
# Out:
# [y(x) == tan(1/4*pi + x)]

# %%
yy=var('yy')
solg=sol_g[0].substitute(y(x)==yy)
show(solg)
# Out:
# yy == tan(1/4*pi + x)

# %%
f(x,yy)=solg
show(f(x,yy))
# Out:
# yy == tan(1/4*pi + x)

# %%
implicit_plot(f(x,yy),(x,-3,1),(yy,-3,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(1/(1-(x^2)))*y+1+x
sol=desolve(eqd,y,ics=[2,0])
f(x)=sol
show(f(x))
list_f=[f(x) for x in [4..15]]
plot(list_f,-2,2)
#show(sol)
# Out:
# 1/2*(sqrt(x^2 - 1)*sqrt(x + 1)*x - sqrt(x + 1)*(2*sqrt(3) - log(2*sqrt(3) + 4)) - sqrt(x + 1)*log(2*x + 2*sqrt(x^2 - 1)))/sqrt(x - 1)
# Graphics object consisting of 13 graphics primitives

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)-2*y==-(x^2)
sol=desolve(eqd,y,ics=[1/4,0])
show(sol)
# Out:
# 1/32*(8*(2*x^2 + 2*x + 1)*e^(1/2) - 13*e^(2*x))*e^(-1/2)

# %%
plot(sol,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-5*diff(y,x)+4*y==0
sol=desolve(eqd,y,ics=[0,5,8])
show(sol)
plot(sol,x,-2,2)
# Out:
# e^(4*x) + 4*e^x
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-4*diff(y,x)+5*y==2*(x^2)*exp(x)
sol=desolve(eqd,y,ics=[0,2,3])
show(sol)
plot(sol,x,-2,2)
# Out:
# (cos(x) - 2*sin(x))*e^(2*x) + (x^2 + 2*x + 1)*e^x
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+4*y==4*(sin(2*x)+cos(2*x))
sol=desolve(eqd,y,ics=[pi,0,2*pi], contrib_ode=True)
show(sol)
# Out:
# 1/2*(2*pi - 1)*cos(2*x) - 1/2*(2*x - 1)*cos(2*x) + x*sin(2*x) + 1/2*sin(2*x)

# %%
plot(sol,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Ex3 (a,d?)

# %%
reset()
x,k= var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(1/x)*y==x^3
_C=var('_C')
sol=desolve(eqd,y)
sol_sub1(x)=sol.substitute(_C==1)

# %%
show(sol_sub1(x))
# Out:
# 1/5*(x^5 + 5)/x

# %%
plot(sol_sub1,x,2,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(sol)
# Out:
# 1/5*(x^5 + 5*_C)/x

# %%
sol1=desolve(eqd,y,ics=[1,0])
show(sol1)
# Out:
# 1/5*(x^5 - 1)/x

# %%
plot(sol1,x,2,3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
sol = integrate((1/cos(x)**2),x)
show(sol)
# Out:
# tan(x)

# %%
sol1 = integrate((2*(x)^2)/((1+(x^2))^2),x)
show(sol1)
# Out:
# -x/(x^2 + 1) + arctan(x)

# %%
sol2 = integrate(sol1,x)
show(sol2)
# Out:
# x*arctan(x) - log(x^2 + 1)

# %%
reset()
x=var('x')
a,b=var('a,b')
y=function('y')(x)
eqd=diff(y,x)==y+a*x+b
sol=desolve(eqd,y,ics=[0,1])
show(sol)
# Out:
# -x + 3*e^x - 2

# %%
reset()
c=var('c')
intg=integrate(exp(2*x+c),x)
show(intg)
# Out:
# 1/2*e^(c + 2*x)

# %%
c=var('c')
show(diff(exp(2*x+c),x))
# Out:
# 2*e^(c + 2*x)

# %%
reset()
x=var('x')
a=var('a')
n=var('n')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)-2*y==0
sol(n)=desolve(eqd,y,ics=[0,a,2])
show(sol(n))
# Out:
# 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)

# %%
show(sol)
# Out:
# n |--> 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)

# %%
sol_l=limit(sol(n),n=infinity)
show(sol_l)
solg=solve(sol_l,x,ivar=a)
# Out:
# 1/3*a*e^(2*x) + 2/3*a*e^(-x) + 2/3*e^(2*x) - 2/3*e^(-x)
